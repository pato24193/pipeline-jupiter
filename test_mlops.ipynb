# %% [markdown]
# <a href="https://colab.research.google.com/github/pato24193/pipeline-jupiter/blob/main/test_mlops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# *   List item
# *   List item

# %% [markdown]
# https://www.coursera.org/learn/devops-dataops-mlops-duke/ungradedLab/YX38l/exploring-jupyter-notebook

# %% [markdown]
# ![mlops-cycle.png](data:image/png;base64,...)
